# %%
# Import Libraries
import torch
import torch.utils.data
#import torch.nn as nn
#import torch.nn.functional as Function
#import torch.optim as optim
#from torch.autograd import Variable
#from scipy import stats, integrate

import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
import time
import pandas as pd

# %%
# Path directory
path = '/Users/khanhnamle/Desktop/CSCI799-Graduate-Independent-Study/Codebase/ml-1m'

# Load datasets from MovieLens1M
movies = pd.read_csv(path + '/movies.dat', sep='::', header=None, engine='python', encoding='latin-1')
users = pd.read_csv(path + '/users.dat', sep='::', header=None, engine='python', encoding='latin-1')
ratings = pd.read_csv(path + '/ratings.dat', sep='::', header=None, engine='python', encoding='latin-1')

# %%
from sklearn.model_selection import train_test_split
# Split the ratings dataframe into 75% training and 25% testing
trainingset, testset = train_test_split(ratings, train_size=0.75)
print(len(trainingset), len(testset))
# Out:
# 750156 250053

# %% [markdown]
# Below are several data pre-processing steps:
# * Convert train and test data into NumPy arrays
# * Get the total number of movies and users to make a data matrix
# * Convert train and test data into PyTorch tensors
# * Convert train and test data into binary values

# %%
# convert to array as it is quicker 
trainingset = np.array(trainingset, dtype='int')
testset = np.array(testset, dtype='int')

# %%
# get total number of movies and users in order to then make a matrix of the data
nb_users = int(max(max(trainingset[:,0]), max(testset[:,0])))
nb_movies = int(max(max(trainingset[:,1]), max(testset[:,1])))
print(nb_users, 'users and', nb_movies, 'movies')
# Out:
# 6040 users and 3952 movies

# %%
# Converting the data into an array with users in lines and movies in columns
def convert(data):
    new_data = [] # initialise list
    for id_users in range(1, nb_users+1):
        id_movies = data[:,1][data[:,0] == id_users]
        id_ratings = data[:,2][data[:,0] == id_users]
        ratings = np.zeros(nb_movies)
        ratings[id_movies - 1] = id_ratings
        new_data.append(list(ratings))
    return new_data

# Apply "convert" function
trainingset = convert(trainingset)
testset = convert(testset)

# %%
# convert data into torch sensors
training_set = torch.FloatTensor(trainingset)
test_set = torch.FloatTensor(testset)

# %%
# convert ratings (1-5) into binary ratings 1 (liked) and 0 (not liked)
training_set[training_set == 0] = -1 # not rated
training_set[training_set == 1] = 0
training_set[training_set == 2] = 0
training_set[training_set >= 3] = 1

test_set[test_set == 0] = -1 # not rated
test_set[test_set == 1] = 0
test_set[test_set == 2] = 0
test_set[test_set >= 3] = 1

# %% [markdown]
# Build the Restricted Boltzmann Machines class:
# * 1 layer of visible units (users' movie preferences whose states we know and set)
# * 1 layer of hidden units (the latent factors we try to learn)
# * A bias unit (adjust for the different inherent popularities of each movie)

# %%
# Create the architecture of the Restricted Boltzmann Machine
class RBM():
    def __init__(self, n_vis, n_hid):
        
        '''
        Initialize the parameters (weights and biases) we optimize during the training process
        @self: the class object
        @n_vis: number of visible units
        @n_hid: number of hidden units
        '''
        
        # Weights used for the probability of the visible units given the hidden units
        self.W = torch.randn(n_hid, n_vis) # torch.rand: random normal distribution mean = 0, variance = 1
        
        # Bias probability of the visible units is activated, given the value of the hidden units (p_v_given_h)
        self.v_bias = torch.randn(1, n_vis) # fake dimension for the batch = 1
        
        # Bias probability of the hidden units is activated, given the value of the visible units (p_h_given_v)
        self.h_bias = torch.randn(1,n_hid) # fake dimension for the batch = 1
    
    def sample_h(self, x):
        
        '''
        Sample the hidden units
        '''
        
        # Probability h is activated given that the value v is sigmoid(Wx + a)
        # torch.mm make the product of 2 tensors
        # W.t() take the transpose because W is used for the p_v_given_h
        wx = torch.mm(x, self.W.t())
        
        # Expand the mini-batch
        activation = wx + self.h_bias.expand_as(wx)
        
        # Calculate the probability p_h_given_v
        p_h_given_v = torch.sigmoid(activation)
        
        # Bernouilli RBM to predict whether an user loves the movie or not (0 or 1)
        # This correspnds to whether the n_hid is activated or not activated
        return p_h_given_v, torch.bernoulli(p_h_given_v)
    
    def sample_v(self, y):
        
        '''
        Sample the visible units
        '''
        
        # Probability v is activated given that the value h is sigmoid(Wx + a)
        wy = torch.mm(y, self.W)
        
        # Expand the mini-batch
        activation = wy + self.v_bias.expand_as(wy)
        
        # Calculate the probability p_v_given_h
        p_v_given_h = torch.sigmoid(activation)
        
        # Bernouilli RBM to predict whether an user loves the movie or not (0 or 1)
        # This correspnds to whether the n_vis is activated or not activated
        return p_v_given_h, torch.bernoulli(p_v_given_h)
    
    def train(self, v0, vk, ph0, phk):
        
        '''
        Perform contrastive divergence algorithm to optimize the weights that minimize the energy
        This maximizes the log-likelihood of the model
        '''
        
        # Approximate the gradients with the CD algorithm
        self.W += (torch.mm(v0.t(), ph0) - torch.mm(vk.t(), phk)).t()
        
        # Add , 0 for the tensor of 2 dimensions
        self.v_bias = torch.sum((v0 - vk), 0)
        self.h_bias = torch.sum((ph0 - phk), 0)

# %% [markdown]
# Create the RBM Object

# %%
# Number of movies
n_vis = len(training_set[0])

# This tunable parameter is the number of features that we want to detect (genre, actors, director, oscar, date....)
n_hid = 100

# Creation of the object of the class RBM()
rbm = RBM(n_vis, n_hid)

# Use Stochastic Gradient Descent to minimize the loss function
#train_op = optim.SGD(rbm.parameters(), 0.1)

# %%
batch_size_ = 100 # set batch size to be 100 (tunable)
reconerr = [] # keep track of reconstruction error
#feerror = [] # keep track of free energy loss

# %% [markdown]
# Train the RBM

# %%
# Keep track of time
start_training_time = time.time()

# %%
# Run for 200 epochs
nb_epoch = 200 # upper bound is not included (nb_epoch + 1)

# First for loop - go through every single epoch
for epoch in range(1, nb_epoch + 1):
    #loss_ = []
    train_recon_error = 0 # reconstruction error initialized to 0 at the beginning of training
    s = 0. # a counter (float type)
    
    # Second for loop - go through every single user
    # Lower bound is 0, upper bound is (nb_users - batch_size_), batch_size_ is the step of each batch (100)
    # The 1st batch is for user with ID = 0 to user with ID = 99
    for id_user in range(0, nb_users - batch_size_, batch_size_):
        
        # At the beginning, v0 = vk. Then we update vk 
        vk = training_set[id_user:id_user + batch_size_]
        #vk = Variable(vk)
        v0 = training_set[id_user:id_user + batch_size_]
        #v0 = Variable(v0)
              
        ph0, _ = rbm.sample_h(v0)
        
        # Third for loop - perform contrastive divergence
        for k in range(10):
            _, hk = rbm.sample_h(vk)
            _, vk = rbm.sample_v(hk)
            
            # We don't want to learn when there is no rating by the user
            # There is no update when rating = -1
            vk[v0 < 0] = v0[v0 < 0]
            
        phk, _ = rbm.sample_h(vk)
        
        # Calculate the loss using contrastive divergence
        # loss = rbm.contrastive_divergence(v0) - rbm.contrastive_divergence(vk)
        rbm.train(v0, vk, ph0, phk)
        #loss_.append(loss.data)
        #train_op.zero_grad()
        #loss.backward()
        #train_op.step()
    
        # Compare vk updated after the traning to v0 (the target)
        train_recon_error += torch.mean(torch.abs(v0[v0 >= 0] - vk[v0 >= 0]))
        s += 1.
    
    # Update reconstruction error
    reconerr.append(train_recon_error / s)
    # Update free energy loss
    #feerror.append(np.mean(loss_))
    
    print('Epoch: ' + str(epoch) + '- Reconstruction Error: ' + str(train_recon_error.data.numpy() / s))
    print("--- Training time is %s seconds ---" % (time.time() - start_training_time))
# Out:
# Epoch: 1- Reconstruction Error: 0.36765705744425453
# --- Training time is 19.222163915634155 seconds ---
# Epoch: 2- Reconstruction Error: 0.37846848169962566
# --- Training time is 34.249520778656006 seconds ---
# Epoch: 3- Reconstruction Error: 0.39547290802001955
# --- Training time is 47.53167366981506 seconds ---
# Epoch: 4- Reconstruction Error: 0.401895809173584
# --- Training time is 60.612146854400635 seconds ---
# Epoch: 5- Reconstruction Error: 0.40025993982950847
# --- Training time is 73.70879983901978 seconds ---
# Epoch: 6- Reconstruction Error: 0.3980916341145833
# --- Training time is 86.23348188400269 seconds ---
# Epoch: 7- Reconstruction Error: 0.4017264684041341
# --- Training time is 100.20252966880798 seconds ---
# Epoch: 8- Reconstruction Error: 0.40320863723754885
# --- Training time is 112.76654696464539 seconds ---
# Epoch: 9- Reconstruction Error: 0.40470927556355796
# --- Training time is 126.17099475860596 seconds ---
# Epoch: 10- Reconstruction Error: 0.40340054829915367
# --- Training time is 139.75455164909363 seconds ---
# Epoch: 11- Reconstruction Error: 0.40313733418782555
# --- Training time is 153.8026008605957 seconds ---
# Epoch: 12- Reconstruction Error: 0.4040859222412109
# --- Training time is 168.7659409046173 seconds ---
# Epoch: 13- Reconstruction Error: 0.4033605893452962
# --- Training time is 181.86012864112854 seconds ---
# Epoch: 14- Reconstruction Error: 0.40368407567342124
# --- Training time is 194.39968276023865 seconds ---
# Epoch: 15- Reconstruction Error: 0.4035990079243978
# --- Training time is 206.61917066574097 seconds ---
# Epoch: 16- Reconstruction Error: 0.40356308619181314
# --- Training time is 220.29992079734802 seconds ---
# Epoch: 17- Reconstruction Error: 0.403617795308431
# --- Training time is 234.80357480049133 seconds ---
# Epoch: 18- Reconstruction Error: 0.40312938690185546
# --- Training time is 250.85178184509277 seconds ---
# Epoch: 19- Reconstruction Error: 0.40288006464640297
# --- Training time is 264.47404980659485 seconds ---
# Epoch: 20- Reconstruction Error: 0.40177415211995443
# --- Training time is 276.963880777359 seconds ---
# Epoch: 21- Reconstruction Error: 0.4031112988789876
# --- Training time is 297.14802980422974 seconds ---
# Epoch: 22- Reconstruction Error: 0.4045077959696452
# --- Training time is 309.98922967910767 seconds ---
# Epoch: 23- Reconstruction Error: 0.403092892964681
# --- Training time is 325.81750774383545 seconds ---
# Epoch: 24- Reconstruction Error: 0.403907839457194
# --- Training time is 341.57012367248535 seconds ---
# Epoch: 25- Reconstruction Error: 0.4042157808939616
# --- Training time is 355.3475058078766 seconds ---
# Epoch: 26- Reconstruction Error: 0.4030529340108236
# --- Training time is 369.3070938587189 seconds ---
# Epoch: 27- Reconstruction Error: 0.40402310689290366
# --- Training time is 383.9804859161377 seconds ---
# Epoch: 28- Reconstruction Error: 0.4040223757425944
# --- Training time is 401.635755777359 seconds ---
# Epoch: 29- Reconstruction Error: 0.40425135294596354
# --- Training time is 414.87366580963135 seconds ---
# Epoch: 30- Reconstruction Error: 0.4036919911702474
# --- Training time is 428.8263506889343 seconds ---
# Epoch: 31- Reconstruction Error: 0.40276864369710286
# --- Training time is 442.3384430408478 seconds ---
# Epoch: 32- Reconstruction Error: 0.40347296396891275
# --- Training time is 455.3830268383026 seconds ---
# Epoch: 33- Reconstruction Error: 0.4036953290303548
# --- Training time is 469.5158348083496 seconds ---
# Epoch: 34- Reconstruction Error: 0.4038769086201986
# --- Training time is 491.3310446739197 seconds ---
# Epoch: 35- Reconstruction Error: 0.4029738744099935
# --- Training time is 529.5536649227142 seconds ---
# Epoch: 36- Reconstruction Error: 0.40272467931111655
# --- Training time is 551.1495249271393 seconds ---
# Epoch: 37- Reconstruction Error: 0.4026026725769043
# --- Training time is 582.5771536827087 seconds ---
# Epoch: 38- Reconstruction Error: 0.40393397013346355
# --- Training time is 602.1845798492432 seconds ---
# Epoch: 39- Reconstruction Error: 0.40270039240519206
# --- Training time is 617.4888997077942 seconds ---
# Epoch: 40- Reconstruction Error: 0.40338783264160155
# --- Training time is 633.0514378547668 seconds ---
# Epoch: 41- Reconstruction Error: 0.4034268379211426
# --- Training time is 647.7522668838501 seconds ---
# Epoch: 42- Reconstruction Error: 0.40355749130249025
# --- Training time is 662.5882139205933 seconds ---
# Epoch: 43- Reconstruction Error: 0.40404510498046875
# --- Training time is 681.1760556697845 seconds ---
# Epoch: 44- Reconstruction Error: 0.40334399541219074
# --- Training time is 698.8909187316895 seconds ---
# Epoch: 45- Reconstruction Error: 0.4040316899617513
# --- Training time is 713.9268207550049 seconds ---
# Epoch: 46- Reconstruction Error: 0.40361337661743163
# --- Training time is 728.0776288509369 seconds ---
# Epoch: 47- Reconstruction Error: 0.4035272280375163
# --- Training time is 742.5408079624176 seconds ---
# Epoch: 48- Reconstruction Error: 0.40279630025227864
# --- Training time is 758.5123698711395 seconds ---
# Epoch: 49- Reconstruction Error: 0.4038630485534668
# --- Training time is 772.8418917655945 seconds ---
# Epoch: 50- Reconstruction Error: 0.40294183095296227
# --- Training time is 787.0351707935333 seconds ---
# Epoch: 51- Reconstruction Error: 0.4034249305725098
# --- Training time is 801.4742107391357 seconds ---
# Epoch: 52- Reconstruction Error: 0.40456908543904624
# --- Training time is 815.8504209518433 seconds ---
# Epoch: 53- Reconstruction Error: 0.403306516011556
# --- Training time is 829.6182289123535 seconds ---
# Epoch: 54- Reconstruction Error: 0.4038893699645996
# --- Training time is 842.5873727798462 seconds ---
# Epoch: 55- Reconstruction Error: 0.40319960912068686
# --- Training time is 857.7296447753906 seconds ---
# Epoch: 56- Reconstruction Error: 0.40396369298299156
# --- Training time is 872.2906188964844 seconds ---
# Epoch: 57- Reconstruction Error: 0.4029819170633952
# --- Training time is 886.5436277389526 seconds ---
# Epoch: 58- Reconstruction Error: 0.4038782755533854
# --- Training time is 900.7415475845337 seconds ---
# Epoch: 59- Reconstruction Error: 0.40343122482299804
# --- Training time is 914.635185956955 seconds ---
# Epoch: 60- Reconstruction Error: 0.4048803965250651
# --- Training time is 928.3027057647705 seconds ---
# Epoch: 61- Reconstruction Error: 0.4038915952046712
# --- Training time is 941.6410617828369 seconds ---
# Epoch: 62- Reconstruction Error: 0.4038413047790527
# --- Training time is 955.5551686286926 seconds ---
# Epoch: 63- Reconstruction Error: 0.40407994588216145
# --- Training time is 969.2728519439697 seconds ---
# Epoch: 64- Reconstruction Error: 0.40342966715494794
# --- Training time is 983.050036907196 seconds ---
# Epoch: 65- Reconstruction Error: 0.4034954388936361
# --- Training time is 1000.1925618648529 seconds ---
# Epoch: 66- Reconstruction Error: 0.4038463274637858
# --- Training time is 1013.9781897068024 seconds ---
# Epoch: 67- Reconstruction Error: 0.40325374603271485
# --- Training time is 1029.30912899971 seconds ---
# Epoch: 68- Reconstruction Error: 0.4024902025858561
# --- Training time is 1041.8202097415924 seconds ---
# Epoch: 69- Reconstruction Error: 0.40390297571818035
# --- Training time is 1054.3896188735962 seconds ---
# Epoch: 70- Reconstruction Error: 0.4026392936706543
# --- Training time is 1067.1328928470612 seconds ---
# Epoch: 71- Reconstruction Error: 0.4030008316040039
# --- Training time is 1079.7328448295593 seconds ---
# Epoch: 72- Reconstruction Error: 0.40332237879435223
# --- Training time is 1092.1637198925018 seconds ---
# Epoch: 73- Reconstruction Error: 0.40285364786783856
# --- Training time is 1106.5991697311401 seconds ---
# Epoch: 74- Reconstruction Error: 0.4031359672546387
# --- Training time is 1119.6148438453674 seconds ---
# Epoch: 75- Reconstruction Error: 0.4032527287801107
# --- Training time is 1135.5616676807404 seconds ---
# Epoch: 76- Reconstruction Error: 0.4032673517862956
# --- Training time is 1152.87437582016 seconds ---
# Epoch: 77- Reconstruction Error: 0.40309178034464516
# --- Training time is 1167.2940559387207 seconds ---
# Epoch: 78- Reconstruction Error: 0.40304587682088217
# --- Training time is 1181.1595888137817 seconds ---
# Epoch: 79- Reconstruction Error: 0.4040631930033366
# --- Training time is 1198.752460718155 seconds ---
# Epoch: 80- Reconstruction Error: 0.40363073348999023
# --- Training time is 1212.331345796585 seconds ---
# Epoch: 81- Reconstruction Error: 0.4025699615478516
# --- Training time is 1226.2153987884521 seconds ---
# Epoch: 82- Reconstruction Error: 0.4025786717732747
# --- Training time is 1240.1823217868805 seconds ---
# Epoch: 83- Reconstruction Error: 0.40398464202880857
# --- Training time is 1253.7858357429504 seconds ---
# Epoch: 84- Reconstruction Error: 0.40333544413248695
# --- Training time is 1266.924974679947 seconds ---
# Epoch: 85- Reconstruction Error: 0.402970822652181
# --- Training time is 1282.2455689907074 seconds ---
# Epoch: 86- Reconstruction Error: 0.40345834096272787
# --- Training time is 1297.1315636634827 seconds ---
# Epoch: 87- Reconstruction Error: 0.4035205841064453
# --- Training time is 1310.8785626888275 seconds ---
# Epoch: 88- Reconstruction Error: 0.4032505671183268
# --- Training time is 1331.4082958698273 seconds ---
# Epoch: 89- Reconstruction Error: 0.4030079205830892
# --- Training time is 1345.3929648399353 seconds ---
# Epoch: 90- Reconstruction Error: 0.4039089520772298
# --- Training time is 1359.4938869476318 seconds ---
# Epoch: 91- Reconstruction Error: 0.40359004338582355
# --- Training time is 1372.1611387729645 seconds ---
# Epoch: 92- Reconstruction Error: 0.40257431666056315
# --- Training time is 1384.6699068546295 seconds ---
# Epoch: 93- Reconstruction Error: 0.40412120819091796
# --- Training time is 1397.1286137104034 seconds ---
# Epoch: 94- Reconstruction Error: 0.40354080200195314
# --- Training time is 1409.5506880283356 seconds ---
# Epoch: 95- Reconstruction Error: 0.4034213701883952
# --- Training time is 1422.1968829631805 seconds ---
# Epoch: 96- Reconstruction Error: 0.40222873687744143
# --- Training time is 1435.3035957813263 seconds ---
# Epoch: 97- Reconstruction Error: 0.40226192474365235
# --- Training time is 1453.1133189201355 seconds ---
# Epoch: 98- Reconstruction Error: 0.40373907089233396
# --- Training time is 1470.2133848667145 seconds ---
# Epoch: 99- Reconstruction Error: 0.40350933074951173
# --- Training time is 1484.3868207931519 seconds ---
# Epoch: 100- Reconstruction Error: 0.4030733108520508
# --- Training time is 1498.1451189517975 seconds ---
# Epoch: 101- Reconstruction Error: 0.4036764144897461
# --- Training time is 1511.4743587970734 seconds ---
# Epoch: 102- Reconstruction Error: 0.4035768191019694
# --- Training time is 1525.884234905243 seconds ---
# Epoch: 103- Reconstruction Error: 0.40421352386474607
# --- Training time is 1538.6888709068298 seconds ---
# Epoch: 104- Reconstruction Error: 0.4038870811462402
# --- Training time is 1552.4616038799286 seconds ---
# Epoch: 105- Reconstruction Error: 0.40332199732462565
# --- Training time is 1566.0967717170715 seconds ---
# Epoch: 106- Reconstruction Error: 0.4028169631958008
# --- Training time is 1579.0094299316406 seconds ---
# Epoch: 107- Reconstruction Error: 0.4035751024881999
# --- Training time is 1592.8233737945557 seconds ---
# Epoch: 108- Reconstruction Error: 0.40308074951171874
# --- Training time is 1608.0873506069183 seconds ---
# Epoch: 109- Reconstruction Error: 0.403685728708903
# --- Training time is 1621.3517718315125 seconds ---
# Epoch: 110- Reconstruction Error: 0.40392436981201174
# --- Training time is 1635.2214317321777 seconds ---
# Epoch: 111- Reconstruction Error: 0.4039535204569499
# --- Training time is 1649.2273578643799 seconds ---
# Epoch: 112- Reconstruction Error: 0.40340058008829754
# --- Training time is 1663.9006178379059 seconds ---
# Epoch: 113- Reconstruction Error: 0.40262660980224607
# --- Training time is 1678.6176698207855 seconds ---
# Epoch: 114- Reconstruction Error: 0.4025010108947754
# --- Training time is 1705.0998978614807 seconds ---
# Epoch: 115- Reconstruction Error: 0.4031606992085775
# --- Training time is 1720.1243948936462 seconds ---
# Epoch: 116- Reconstruction Error: 0.4033880869547526
# --- Training time is 1734.9893128871918 seconds ---
# Epoch: 117- Reconstruction Error: 0.4031434694925944
# --- Training time is 1751.6393926143646 seconds ---
# Epoch: 118- Reconstruction Error: 0.40463644663492837
# --- Training time is 1768.59481883049 seconds ---
# Epoch: 119- Reconstruction Error: 0.40368531545003256
# --- Training time is 1786.4342968463898 seconds ---
# Epoch: 120- Reconstruction Error: 0.4029748280843099
# --- Training time is 1804.3969867229462 seconds ---
# Epoch: 121- Reconstruction Error: 0.4027366638183594
# --- Training time is 1820.700484752655 seconds ---
# Epoch: 122- Reconstruction Error: 0.4036316235860189
# --- Training time is 1834.3788077831268 seconds ---
# Epoch: 123- Reconstruction Error: 0.4030216852823893
# --- Training time is 1848.1822447776794 seconds ---
# Epoch: 124- Reconstruction Error: 0.40334033966064453
# --- Training time is 1862.7845838069916 seconds ---
# Epoch: 125- Reconstruction Error: 0.4037021001180013
# --- Training time is 1884.3533928394318 seconds ---
# Epoch: 126- Reconstruction Error: 0.4028518040974935
# --- Training time is 1902.7802937030792 seconds ---
# Epoch: 127- Reconstruction Error: 0.4026836077372233
# --- Training time is 1921.6258628368378 seconds ---
# Epoch: 128- Reconstruction Error: 0.4028422991434733
# --- Training time is 1946.043911933899 seconds ---
# Epoch: 129- Reconstruction Error: 0.4037604331970215
# --- Training time is 1969.8077137470245 seconds ---
# Epoch: 130- Reconstruction Error: 0.40350093841552737
# --- Training time is 1990.250180721283 seconds ---
# Epoch: 131- Reconstruction Error: 0.40374269485473635
# --- Training time is 2008.7126047611237 seconds ---
# Epoch: 132- Reconstruction Error: 0.40401363372802734
# --- Training time is 2022.9580867290497 seconds ---
# Epoch: 133- Reconstruction Error: 0.40419902801513674
# --- Training time is 2046.222702741623 seconds ---
# Epoch: 134- Reconstruction Error: 0.4039202372233073
# --- Training time is 2066.068459749222 seconds ---
# Epoch: 135- Reconstruction Error: 0.40395679473876955
# --- Training time is 2103.7545416355133 seconds ---
# Epoch: 136- Reconstruction Error: 0.40285634994506836
# --- Training time is 2119.617374897003 seconds ---
# Epoch: 137- Reconstruction Error: 0.40240675608317056
# --- Training time is 2132.39492893219 seconds ---
# Epoch: 138- Reconstruction Error: 0.40403820673624674
# --- Training time is 2146.4714980125427 seconds ---
# Epoch: 139- Reconstruction Error: 0.40365575154622396
# --- Training time is 2164.8940889835358 seconds ---
# Epoch: 140- Reconstruction Error: 0.40346883138020834
# --- Training time is 2182.6536087989807 seconds ---
# Epoch: 141- Reconstruction Error: 0.4043924331665039
# --- Training time is 2200.920425891876 seconds ---
# Epoch: 142- Reconstruction Error: 0.40385154088338215
# --- Training time is 2215.499737739563 seconds ---
# Epoch: 143- Reconstruction Error: 0.40304911931355797
# --- Training time is 2231.1794958114624 seconds ---
# Epoch: 144- Reconstruction Error: 0.4028303782145182
# --- Training time is 2247.051417827606 seconds ---
# Epoch: 145- Reconstruction Error: 0.4034303665161133
# --- Training time is 2261.4847497940063 seconds ---
# Epoch: 146- Reconstruction Error: 0.4037429491678874
# --- Training time is 2276.636584997177 seconds ---
# Epoch: 147- Reconstruction Error: 0.403242301940918
# --- Training time is 2290.5141739845276 seconds ---
# Epoch: 148- Reconstruction Error: 0.4026126543680827
# --- Training time is 2308.3910195827484 seconds ---
# Epoch: 149- Reconstruction Error: 0.40235894521077475
# --- Training time is 2327.1564197540283 seconds ---
# Epoch: 150- Reconstruction Error: 0.4032894134521484
# --- Training time is 2351.7161667346954 seconds ---
# Epoch: 151- Reconstruction Error: 0.4028027534484863
# --- Training time is 2370.661401748657 seconds ---
# Epoch: 152- Reconstruction Error: 0.40280605951944987
# --- Training time is 2387.594314813614 seconds ---
# Epoch: 153- Reconstruction Error: 0.40303243001302086
# --- Training time is 2405.71306681633 seconds ---
# Epoch: 154- Reconstruction Error: 0.40298678080240885
# --- Training time is 2419.1987116336823 seconds ---
# Epoch: 155- Reconstruction Error: 0.40315240224202475
# --- Training time is 2432.389760017395 seconds ---
# Epoch: 156- Reconstruction Error: 0.40371901194254556
# --- Training time is 2446.003502845764 seconds ---
# Epoch: 157- Reconstruction Error: 0.4020355224609375
# --- Training time is 2461.4091608524323 seconds ---
# Epoch: 158- Reconstruction Error: 0.40285174051920575
# --- Training time is 2477.085836648941 seconds ---
# Epoch: 159- Reconstruction Error: 0.4029845873514811
# --- Training time is 2491.9574887752533 seconds ---
# Epoch: 160- Reconstruction Error: 0.40274225870768227
# --- Training time is 2508.9294097423553 seconds ---
# Epoch: 161- Reconstruction Error: 0.40355027516682945
# --- Training time is 2524.1822566986084 seconds ---
# Epoch: 162- Reconstruction Error: 0.403173287709554
# --- Training time is 2537.055937767029 seconds ---
# Epoch: 163- Reconstruction Error: 0.4033798853556315
# --- Training time is 2549.7349588871 seconds ---
# Epoch: 164- Reconstruction Error: 0.4028077761332194
# --- Training time is 2564.495271921158 seconds ---
# Epoch: 165- Reconstruction Error: 0.40306584040323895
# --- Training time is 2581.7260978221893 seconds ---
# Epoch: 166- Reconstruction Error: 0.4023621877034505
# --- Training time is 2595.8094437122345 seconds ---
# Epoch: 167- Reconstruction Error: 0.4033037185668945
# --- Training time is 2613.626754760742 seconds ---
# Epoch: 168- Reconstruction Error: 0.4025904655456543
# --- Training time is 2627.5166568756104 seconds ---
# Epoch: 169- Reconstruction Error: 0.4020807902018229
# --- Training time is 2658.595811843872 seconds ---
# Epoch: 170- Reconstruction Error: 0.40310182571411135
# --- Training time is 2679.8753678798676 seconds ---
# Epoch: 171- Reconstruction Error: 0.4032623291015625
# --- Training time is 2695.7550468444824 seconds ---
# Epoch: 172- Reconstruction Error: 0.40249929428100584
# --- Training time is 2714.8796668052673 seconds ---
# Epoch: 173- Reconstruction Error: 0.4028156280517578
# --- Training time is 2730.06401181221 seconds ---
# Epoch: 174- Reconstruction Error: 0.40417207082112633
# --- Training time is 2742.017228603363 seconds ---
# Epoch: 175- Reconstruction Error: 0.4037142753601074
# --- Training time is 2754.128579854965 seconds ---
# Epoch: 176- Reconstruction Error: 0.4038778940836589
# --- Training time is 2767.352770805359 seconds ---
# Epoch: 177- Reconstruction Error: 0.40387083689371744
# --- Training time is 2779.616883993149 seconds ---
# Epoch: 178- Reconstruction Error: 0.40374886194864906
# --- Training time is 2792.0370528697968 seconds ---
# Epoch: 179- Reconstruction Error: 0.4034910202026367
# --- Training time is 2805.8601038455963 seconds ---
# Epoch: 180- Reconstruction Error: 0.4030829747517904
# --- Training time is 2818.220170021057 seconds ---
# Epoch: 181- Reconstruction Error: 0.4034712791442871
# --- Training time is 2829.9789958000183 seconds ---
# Epoch: 182- Reconstruction Error: 0.4029813766479492
# --- Training time is 2841.787612915039 seconds ---
# Epoch: 183- Reconstruction Error: 0.40270732243855795
# --- Training time is 2853.533404827118 seconds ---
# Epoch: 184- Reconstruction Error: 0.4028965950012207
# --- Training time is 2865.2704458236694 seconds ---
# Epoch: 185- Reconstruction Error: 0.40373503367106117
# --- Training time is 2877.1385610103607 seconds ---
# Epoch: 186- Reconstruction Error: 0.4031478563944499
# --- Training time is 2888.852516889572 seconds ---
# Epoch: 187- Reconstruction Error: 0.40355739593505857
# --- Training time is 2900.6505715847015 seconds ---
# Epoch: 188- Reconstruction Error: 0.4033601442972819
# --- Training time is 2912.4756877422333 seconds ---
# Epoch: 189- Reconstruction Error: 0.4027962366739909
# --- Training time is 2924.4053859710693 seconds ---
# Epoch: 190- Reconstruction Error: 0.40273841222127277
# --- Training time is 2936.088122844696 seconds ---
# Epoch: 191- Reconstruction Error: 0.4035798072814941
# --- Training time is 2947.9639077186584 seconds ---
# Epoch: 192- Reconstruction Error: 0.4027690887451172
# --- Training time is 2960.593382835388 seconds ---
# Epoch: 193- Reconstruction Error: 0.4028967539469401
# --- Training time is 2973.481024980545 seconds ---
# Epoch: 194- Reconstruction Error: 0.40402418772379556
# --- Training time is 2985.8635337352753 seconds ---
# Epoch: 195- Reconstruction Error: 0.4028937021891276
# --- Training time is 2999.0475409030914 seconds ---
# Epoch: 196- Reconstruction Error: 0.40317217508951825
# --- Training time is 3012.269549846649 seconds ---
# Epoch: 197- Reconstruction Error: 0.4034648259480794
# --- Training time is 3024.9207859039307 seconds ---
# Epoch: 198- Reconstruction Error: 0.40330270131429036
# --- Training time is 3038.370547771454 seconds ---
# Epoch: 199- Reconstruction Error: 0.40380605061848956
# --- Training time is 3050.2089936733246 seconds ---
# Epoch: 200- Reconstruction Error: 0.4029826800028483
# --- Training time is 3062.1619398593903 seconds ---

# %%
# Plot the recostruction error with respect to increasing number of epochs
plt.plot(reconerr)
plt.ylabel('Training Data Reconstruction Error')
plt.xlabel('Epoch')
plt.show()

# %%
# Keep track of time
start_test_time = time.time()

# %%
# Testing
test_recon_error = 0 # reconstruction error initialized to 0 at the beginning of training
s = 0. # a counter (float type) 
# test_free_energy_loss = []

for id_user in range(nb_users): # batch learning
    v = training_set[id_user:id_user + 1]  # training set inputs are used to activate neurons of my RBM
    vt = test_set[id_user:id_user + 1] # target
    
    #v = Variable(v)
    #vt = Variable(vt)
    
    if len(vt[vt >= 0]) > 0:
        _, h = rbm.sample_h(v)
        _ ,v = rbm.sample_v(h)
        
        # Update test reconstruction error
        test_recon_error += torch.mean(torch.abs(vt[vt >= 0] - v[vt >= 0]))
        s += 1.
    
    #v = v.data.numpy()
    #test_free_energy_loss.append(v)

print ('Reconstructions error:  ' +  str(test_recon_error.data.numpy() / s))
print("--- Test time is %s seconds ---" % (time.time() - start_test_time))
# Out:
# Reconstructions error:  0.42058368737835433
# --- Test time is 3.172278881072998 seconds ---
